# %%
import pandas as pd

# %%
df1 = pd.read_csv("JC-201906-citibike-tripdata.csv")

# %%
df2 = pd.read_csv("JC-201806-citibike-tripdata-Copy1.csv")

# %%
df3 = pd.read_csv("JC-201706-citibike-tripdata.csv")
df3
# Out:
#        tripduration            starttime             stoptime  \
# 0               499  2017-06-01 00:01:39  2017-06-01 00:09:59
# 1               507  2017-06-01 00:06:39  2017-06-01 00:15:07
# 2               768  2017-06-01 00:44:43  2017-06-01 00:57:31
# 3               101  2017-06-01 01:12:55  2017-06-01 01:14:36
# 4               265  2017-06-01 01:14:00  2017-06-01 01:18:25
# 5               588  2017-06-01 01:16:51  2017-06-01 01:26:40
# 6               345  2017-06-01 01:17:02  2017-06-01 01:22:48
# 7               764  2017-06-01 01:17:43  2017-06-01 01:30:27
# 8               257  2017-06-01 01:34:00  2017-06-01 01:38:18
# 9               315  2017-06-01 02:14:04  2017-06-01 02:19:19
# 10              379  2017-06-01 02:49:47  2017-06-01 02:56:06
# 11              625  2017-06-01 03:35:43  2017-06-01 03:46:08
# 12              284  2017-06-01 04:03:59  2017-06-01 04:08:43
# 13              185  2017-06-01 04:22:14  2017-06-01 04:25:20
# ...

# %%
merged_table = pd.concat([df1 , df2, df3])
merged_table
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1               280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 2              2162  2019-06-01 00:13:11.8800  2019-06-01 00:49:14.3640
# 3              2184  2019-06-01 00:13:30.1110  2019-06-01 00:49:54.2250
# 4               139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
# 5               203  2019-06-01 00:15:43.2590  2019-06-01 00:19:06.7450
# 6               671  2019-06-01 00:19:41.5790  2019-06-01 00:30:52.6600
# 7               271  2019-06-01 00:19:59.6030  2019-06-01 00:24:31.1770
# 8               172  2019-06-01 00:22:26.0000  2019-06-01 00:25:18.9340
# 9               763  2019-06-01 00:23:00.7680  2019-06-01 00:35:44.3800
# 10              222  2019-06-01 00:24:54.1970  2019-06-01 00:28:36.5740
# 11              358  2019-06-01 00:24:54.7060  2019-06-01 00:30:53.3590
# ...

# %%
pd.concat([df1 , df2, df3]).to_csv("TripData.csv")

# %%
# school_type = merge_table.groupby("school_name")["type"].unique()



# coords = merged_table.groupby('start station id')["start station name"].unique()


coords = merged_table["start station name"].unique()
len(coords)

end_coords = merged_table["end station name"].unique()
len(end_coords)
# Out:
# 97

# %%
coords = merged_table.groupby('start station name')["start station name"].unique()

# %%
# df['count'] = 1

# df.groupby(['Type 1', 'Type 2']).count() ['count']


gender_df = merged_table.groupby(['gender', 'starttime']).sum() 

gender_df

# %%
gender_df.to_csv("genderData.csv")

# %%
merged_table.groupby(['gender']).count()
